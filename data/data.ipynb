# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Daylio_Abid.csv')

# %%
data
# Out:
#       full_date    date    weekday      time   sub_mood  \
# 0    16/04/2021  Apr-16     Friday   8:00 pm       yolo
# 1    15/04/2021  Apr-15   Thursday   2:37 am   focused
# 2    14/04/2021  Apr-14  Wednesday   2:39 am  confused
# 3    13/04/2021  Apr-13    Tuesday   2:38 am  wondering
# 4    12/04/2021  Apr-12     Monday   9:52 pm      angry
# ..          ...     ...        ...       ...        ...
# 935  04/02/2018  Feb-04     Sunday   8:19 pm       yolo
# 936  04/02/2018  Feb-04     Sunday  11:23 am        meh
# 937  04/02/2018  Feb-04     Sunday   6:34 am   blessed
# 938  03/02/2018  Feb-03   Saturday   7:52 pm      angry
# 939  03/02/2018  Feb-03   Saturday   3:12 pm        meh
#
#                                             activities    mood
# 0    reading | Art | prayer | fasting  | walk | med...    Good
# 1    reading | learning  | Art | prayer | fasting  ...    Good
# 2    reading | learning  | prayer | fasting  | Qura...  Normal
# ...

# %%
new_date = data[:10]

# %%
new_date
# Out:
#     full_date    date    weekday      time   sub_mood  \
# 0  16/04/2021  Apr-16     Friday   8:00 pm       yolo
# 1  15/04/2021  Apr-15   Thursday   2:37 am   focused
# 2  14/04/2021  Apr-14  Wednesday   2:39 am  confused
# 3  13/04/2021  Apr-13    Tuesday   2:38 am  wondering
# 4  12/04/2021  Apr-12     Monday   9:52 pm      angry
# 5  11/04/2021  Apr-11     Sunday  12:21 am  wondering
# 6  10/04/2021  Apr-10   Saturday  12:20 am   blessed
# 7  09/04/2021  Apr-09     Friday  12:20 am       yolo
# 8  08/04/2021  Apr-08   Thursday  11:07 pm   excited
# 9  07/04/2021  Apr-07  Wednesday   9:02 pm       yolo
#
#                                           activities     mood
# 0  reading | Art | prayer | fasting  | walk | med...     Good
# 1  reading | learning  | Art | prayer | fasting  ...     Good
# 2  reading | learning  | prayer | fasting  | Qura...   Normal
# 3  reading | learning  | Art | prayer | fasting  ...   Normal
# ...

# %%
weekday_dict = {'Monday': 1, 'Tuesday': 2, 'Wednesday': 3, 'Thursday': 4, 'Friday': 5, 'Saturday': 6, 'Sunday': 7}
new_date['weekday_num'] = new_date['weekday'].map(weekday_dict)
new_date = new_date.sort_values('weekday_num')

plt.figure(figsize=(10, 6))
plt.plot(new_date['weekday'], new_date['mood'], marker='o', color='b', linestyle='-')
plt.title('Mood vs. Weekday')
plt.xlabel('Weekday')
plt.ylabel('Mood')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
